# %% [markdown]
# # **Lista final sobre regressão linear**
#
# Em anexo tem dois arquivos:
#    - profit.py
#    - data.txt
#
#
# Salve ambos na mesma pasta.
# Você deverá criar um modelo de regressão linear que preveja o lucro(profit) de um food truck.

# %%
# Importando as bibliotecas

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score 
from sklearn.linear_model import LinearRegression
from sklearn import svm
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor 
from sklearn.model_selection import train_test_split

# %%
# Trazendo os dados

df = pd.read_csv('/content/ex1data1.txt')
df
# Out:
#     Population    Profit
# 0       6.1101  17.59200
# 1       5.5277   9.13020
# 2       8.5186  13.66200
# 3       7.0032  11.85400
# 4       5.8598   6.82330
# ..         ...       ...
# 92      5.8707   7.20290
# 93      5.3054   1.98690
# 94      8.2934   0.14454
# 95     13.3940   9.05510
# 96      5.4369   0.61705
#
# [97 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Population  97 non-null     float64
#  1   Profit      97 non-null     float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %%
df.describe()
# Out:
#        Population     Profit
# count   97.000000  97.000000
# mean     8.159800   5.839135
# std      3.869884   5.510262
# min      5.026900  -2.680700
# 25%      5.707700   1.986900
# 50%      6.589400   4.562300
# 75%      8.578100   7.046700
# max     22.203000  24.147000

# %%
# Correlação

fig, ax = plt.subplots(figsize=(8, 6))

sns.heatmap(df.corr(), annot = True, center=0,  cmap="rocket", vmin=-0.9, vmax=1)
ax.set(title="Tabela de Correlação Linear entre as variaveis");

# %%
sns.regplot(x="Population", y="Profit", data=df);

# %%
# Utilizando o modelo de regressão linear simples da sklearn para prever Y = Profit/Lucro através de X = População

# Definindo as variaveis
X = df[['Population']]
y = df[['Profit']]

# Separando em base de treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# Cria o objeto sklearn do regressor linear
regressor = LinearRegression()

# Treina o modelo com os parametros da base de dados de teste
regressor.fit(X_train,y_train)

# Realiza a previsão para a base de dados de Treino
y_pred = regressor.predict(X_test)

print("A reta treinada para a Regressão Linear é: y = ", regressor.intercept_[0], "+ X*",regressor.coef_[0][0], '\n' )
# Out:
# A reta treinada para a Regressão Linear é: y =  -4.1061605135817105 + X* 1.2093499147006523
