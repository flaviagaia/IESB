# %% [markdown]
# ## **Trabalho de Análise de Algoritmo**
#
# Grupo: Fábio Laporte, Flávia Gaia e Valdeci dos Santos
#
# Professor: Rodrigo Hagstrom

# %% [markdown]
# **Insertion Sort e Selection Sort com contadores de operações**
#
# Implementar os dois algoritmos (Insertion e Selection Sort) em linguagem C ou Python, com contadores e comparar o desempenho dos dois. Será que há diferença significativa? Do ponto de vista assintótico, vimos na aula que não.
#
#
# Data de entrega: **24 de abr**. 23:59

# %% [markdown]
# https://www.devmedia.com.br/algoritmos-de-ordenacao-analise-e-comparacao/28261
#
# https://www.geeksforgeeks.org/python-program-for-insertion-sort/

# %%
# Cada linha é 1x, for e while n vezes, n^2 vezes

# %%
# Insertion Sort:
  
def insertionSort(arr):
    # Atravessar de 1 para len (arr):
    for i in range(1, len(arr)):
        key = arr[i]
       # Mova os elementos de arr [0..i-1], que são 
       # maior que chave, para uma posição à frente 
       # de sua posição atual:
        j = i-1
        while j >=0 and key < arr[j] :
                arr[j+1] = arr[j]
                j -= 1
        arr[j+1] = key

# Testando a função acima:
arr = [12, 11, 13, 5, 6]
insertionSort(arr)
print ("A matriz classificada é:")
for i in range(len(arr)):
    print ("%d" %arr[i])
# Out:
# A matriz classificada é:
# 5
# 6
# 11
# 12
# 13

# %%
# Selection Sort:

import sys
A = [64, 25, 12, 22, 11]

# Percorrer todos os elementos da matriz:
for i in range(len(A)):
	
	# Encontre o elemento mínimo remanescente 
  # do array não classificado:
	min_idx = i
	for j in range(i+1, len(A)):
		if A[min_idx] > A[j]:
			min_idx = j
			
	# Troque o elemento mínimo encontrado por 
  # o primeiro elemento:	
	A[i], A[min_idx] = A[min_idx], A[i]

# Testando a função acima:
print ("Matriz ordenada")
for i in range(len(A)):
	print("%d" %A[i]),
# Out:
# Matriz ordenada
# 11
# 12
# 22
# 25
# 64
