# %% [markdown]
# # **Trabalho Final Segundo Bimestre**
#
# #Os estudantes deverão escolher um problemas, por exemplo, do caixeiro viajante ou outro problema difícil (tempo não polinomial), implementar, e fazer testes para diferentes volumes ou tamanhos de entradas. Demonstração em sala de aula no dia 12 de junho.
#
#
# Aluna: Flávia Gaia.
#
# Professor: Rodrigo Hagstrom.
#
# Data de entrega: 12 de jun. 10:00
